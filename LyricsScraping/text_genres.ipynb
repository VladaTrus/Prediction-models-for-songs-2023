# %%
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle
import os
import re

# %% [markdown]
# ## Конечная классификации по жанрам

# %%
def load_from_json(filename):
    """Load data from a JSON file."""
    if os.path.exists(filename):
        with open(filename, 'r') as json_file:
            return json.load(json_file)
    else:
        return {}

# %%
df_tracks = pd.read_pickle('tracks_df.pickle')

# %%
eng_tracks = load_from_json('lyrics_eng_fin.json')
len(eng_tracks)
# Out:
# 32729

# %%
other_tracks = load_from_json('lyrics_other_fin.json')
len(other_tracks)
# Out:
# 6048

# %%
df_tracks.head()
# Out:
#   album_type                album_id                 album_name  \
# 0      album  6Kssm2LosQ0WyLukFZkEG5                       Demi
# 1     single  65L5VcKGKe6sOJIPNFc0Q1           One in a Million
# 2     single  5Q5PomrTdI13qpmEeM393B       On My Love (Sped Up)
# 3      album  6fpLLJsDSSAlToEDW2jv4F  Animal (Expanded Edition)
# 4      album  20Ol6zZ0nLlc5EGTH1zA0j          Delirium (Deluxe)
#
#   album_release_data                                album_artists_names  \
# 0         2013-01-01                                        Demi Lovato
# 1         2023-08-04    Bebe Rexha:artist_custom_separator:David Guetta
# 2         2023-09-12  Zara Larsson:artist_custom_separator:David Guetta
# 3         2010-01-01                                              Kesha
# 4         2015-11-06                                     Ellie Goulding
#
#                                    album_artists_ids  album_total_tracks  \
# 0                             6S2OmqARrzebs0tKUEyXyp                  13
# 1  64M6ah0SkkRsnPGtGiRAbb:artist_custom_separator...                   1
# 2  1Xylc3o4UrD53lo9CvFvVg:artist_custom_separator...                   4
# 3                             6LqNN22kT3074XbTVUrhzX                  18
# 4                             0X2BH1fck6amBIoJhDVmmJ                  22
#
#                                  track_artists_names  \
# 0                                        Demi Lovato
# 1    Bebe Rexha:artist_custom_separator:David Guetta
# 2  Zara Larsson:artist_custom_separator:David Guetta
# 3                                              Kesha
# 4                                     Ellie Goulding
#
#                                    track_artists_ids  \
# 0                             6S2OmqARrzebs0tKUEyXyp
# 1  64M6ah0SkkRsnPGtGiRAbb:artist_custom_separator...
# 2  1Xylc3o4UrD53lo9CvFvVg:artist_custom_separator...
# 3                             6LqNN22kT3074XbTVUrhzX
# 4                             0X2BH1fck6amBIoJhDVmmJ
#
#                                           track_name  ...  \
# 0                                       Heart Attack  ...
# 1                                   One in a Million  ...
# 2                                         On My Love  ...
# 3                                            TiK ToK  ...
# 4  Love Me Like You Do - From "Fifty Shades Of Grey"  ...
#
#                        id                                   uri  \
# 0  1V6gIisPpYqgFeWbMLI0bA  spotify:track:1V6gIisPpYqgFeWbMLI0bA
# 1  3YfGTvsTAWGC2lgoDOikUz  spotify:track:3YfGTvsTAWGC2lgoDOikUz
# 2  0K6iKgHPPhAb4Acmg9aD77  spotify:track:0K6iKgHPPhAb4Acmg9aD77
# 3  0HPD5WQqrq7wPWR7P7Dw1i  spotify:track:0HPD5WQqrq7wPWR7P7Dw1i
# 4  3zHq9ouUJQFQRf3cm1rRLu  spotify:track:3zHq9ouUJQFQRf3cm1rRLu
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/1V6gIisPpYqg...
# 1  https://api.spotify.com/v1/tracks/3YfGTvsTAWGC...
# 2  https://api.spotify.com/v1/tracks/0K6iKgHPPhAb...
# 3  https://api.spotify.com/v1/tracks/0HPD5WQqrq7w...
# 4  https://api.spotify.com/v1/tracks/3zHq9ouUJQFQ...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/1V6g...       210840
# 1  https://api.spotify.com/v1/audio-analysis/3YfG...       160530
# 2  https://api.spotify.com/v1/audio-analysis/0K6i...       222912
# 3  https://api.spotify.com/v1/audio-analysis/0HPD...       199693
# 4  https://api.spotify.com/v1/audio-analysis/3zHq...       252534
#
#    time_signature             playlist_id  genre  total_followers  \
# 0               4  6gS3HhOiI17QNojjPuPzqc    pop          22857.0
# 1               4  6gS3HhOiI17QNojjPuPzqc    pop          22857.0
# 2               4  6gS3HhOiI17QNojjPuPzqc    pop          22857.0
# 3               4  6gS3HhOiI17QNojjPuPzqc    pop          22857.0
# 4               4  6gS3HhOiI17QNojjPuPzqc    pop          22857.0
#
#    total_tracks
# 0           428
# 1           428
# 2           428
# 3           428
# 4           428
#
# [5 rows x 37 columns]

# %%
df_tracks.shape
# Out:
# (145732, 39)

# %%
df_tracks.drop_duplicates('id', inplace=True)

# %%
df_tracks.shape
# Out:
# (126997, 39)

# %%
df_tracks['lyrics_eng'] = df_tracks['id'].map(lambda x: eng_tracks.get(x, {}).get('lyrics'))
df_tracks['lyrics_other'] = df_tracks['id'].map(lambda x: other_tracks.get(x, {}).get('lyrics'))

# %%
df_tracks.genre.nunique()
# Out:
# 1477

# %%
def count_tracks(series):
    with_lyrics = series.count()
    n_tracks = len(series)
    return pd.Series({'with_lyrics': with_lyrics})

result = df_tracks.groupby('genre').agg(
    lyrics_eng=('lyrics_eng', count_tracks),
    lyrics_other=('lyrics_other', count_tracks),
    n_songs=('genre', 'size')
).reset_index()

# %%
result.head()
# Out:
#               genre  lyrics_eng  lyrics_other  n_songs
# 0      5th wave emo          36             0       51
# 1      aarhus indie          16             7       97
# 2  abstract hip hop          35             0       64
# 3         acid rock          28             3       85
# 4      acoustic pop          63             0       80

# %%
result.genre.nunique(), result.n_songs.sum()
# Out:
# (1477, 126997)

# %% [markdown]
# Дропаем `def_not_english`

# %%
def_not_english = result[(result['lyrics_eng'] == 0) & (result['lyrics_other'] >= 0)]
print(def_not_english['genre'].nunique(), def_not_english['n_songs'].sum())
# Out:
# 130 11997

# %%
filt_genres = result.query('not (lyrics_eng == 0 and lyrics_other >= 0)')
filt_genres.shape
# Out:
# (1347, 4)

# %% [markdown]
# **Вопрос1:** что делать с `mainly_not_english`

# %%
mainly_not_english = filt_genres[filt_genres['lyrics_eng'] < filt_genres['lyrics_other']].sort_values('lyrics_other', ascending=False)
mainly_not_english['lyrics_eng'].sum()
# Out:
# 616

# %%
mainly_not_english.shape
# Out:
# (174, 4)

# %% [markdown]
# С этим мы работаем `eng_genres`

# %%
eng_genres = filt_genres.query('not lyrics_eng < lyrics_other')
eng_genres.sort_values(['lyrics_eng','n_songs'], ascending=False).head(50)
# Out:
#                            genre  lyrics_eng  lyrics_other  n_songs
# 1025                         pop         100             0      100
# 1116                         rap         100             0      100
# 1179                        rock          99             0      100
# 1256       singer-songwriter pop          96             0      100
# 269   christian alternative rock          88             0       99
# 1067                  pov: indie          88             2       92
# 862                  modern rock          88             1       89
# 320         contemporary country          87             0      100
# 615                     hyperpop          87             0       98
# 26             alternative metal          87             0       87
# 1396                  uk hip hop          86             0      100
# 822                    metalcore          84             0       91
# 857             modern indie pop          83             0       96
# 30               alternative r&b          83             0       95
# 1039                    pop punk          83             0       95
# 217                 canadian pop          83             1       93
# 1030                   pop dance          82             1       95
# 310                    cloud rap          81             1       96
# 634                   indie folk          80             1       94
# 850           modern country pop          79             0      100
# 847       modern alternative pop          79             0       92
# 1069                 power metal          79             0       87
# 1100                        punk          79             0       87
# 1268            social media pop          77             1       99
# 585             hard alternative          77             0       96
# 137                 bedroom soul          77             0       95
# 1400                      uk pop          77             0       87
# 57                       art pop          76             3       93
# 455                          emo          76             0       86
# 758                  lo-fi indie          75             1       96
# 89            australian hip hop          74             1       98
# 649                indie pop rap          73             0       92
# 1373                   trap soul          73             0       86
# 136                  bedroom pop          73             1       84
# 280               christian rock          73             0       83
# 266                    chill pop          72             1       93
# 1214                     sad rap          72             1       92
# 959                      nyc pop          72             0       88
# 1390          uk alternative pop          71             1       96
# 802                  melodic rap          71             0       76
# 277                christian pop          70             0       94
# 39            american metalcore          70             0       92
# 637            indie garage rock          70             1       89
# 462           english indie rock          70             0       88
# 273            christian hip hop          69             1       98
# 569                   grunge pop          69             0       93
# 1045                    pop soul          69             0       91
# 8                  aesthetic rap          68             1       99
# 210             canadian hip hop          68             1       93
# 90              australian indie          68             0       88

# %% [markdown]
# **Вопрос2:** по разбиению жанров, я предлагаю 10 ниже, которые указаны ниже (hip hop в один сольется).
#
#
# И добрать песен еще, чтоб +/- равно было.
#
# Можно убрать 'folk',
#   'country',
#   'soul'

# %%
from collections import Counter
word_counts = Counter(' '.join(eng_genres['genre']).lower().split())

word_counts_df = pd.DataFrame(list(word_counts.items()), columns=['word', 'count']).sort_values('count', ascending=False).head(15)

genres = word_counts_df.word.tolist()
genres = [g for g in genres if g not in ['black', 'canadian', 'alternative', 'deep']]

# %%
genres, len(genres)
# Out:
# (['indie',
#   'metal',
#   'rock',
#   'pop',
#   'hip',
#   'hop',
#   'punk',
#   'rap',
#   'folk',
#   'country',
#   'soul'],
#  11)

# %%
def create_final_genre(genre):
    final_genre = [word for word in genres if word in genre.lower()]
    if 'hip' in final_genre and 'hop' in final_genre:
        final_genre.remove('hip')
        final_genre.remove('hop')
        final_genre.append('hip hop')
    return final_genre

eng_genres['final_genre'] = eng_genres['genre'].apply(create_final_genre)
eng_genres.shape
# Out:
# <ipython-input-90-fd91e866b08b>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eng_genres['final_genre'] = eng_genres['genre'].apply(create_final_genre)
# (1173, 6)

# %%
eng_genres_filtered = eng_genres[eng_genres['final_genre'].apply(lambda x: len(x) > 0)]
eng_genres_filtered.shape
# Out:
# (1102, 6)

# %%
one_genre = eng_genres_filtered[eng_genres_filtered['final_genre'].apply(lambda x: len(x) == 1)]
one_genre['final_genre'] = one_genre['final_genre'].apply(tuple)
one_genre
# Out:
# <ipython-input-92-680114186ec2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_genre['final_genre'] = one_genre['final_genre'].apply(tuple)
#                  genre  lyrics_eng  lyrics_other  n_songs       norm  \
# 1         aarhus indie          16             7       97  16.494845
# 2     abstract hip hop          35             0       64  54.687500
# 3            acid rock          28             3       85  32.941176
# 4         acoustic pop          63             0       80  78.750000
# 5        acoustic punk          18             0       53  33.962264
# ...                ...         ...           ...      ...        ...
# 1472        yacht rock          41             1       73  56.164384
# 1473        york indie          24             0       91  26.373626
# 1474    yorkshire folk           8             0       72  11.111111
# 1475       zim hip hop          10             3      100  10.000000
# 1476      zurich indie          17             2       99  17.171717
#
#      final_genre
# 1       (indie,)
# 2     (hip hop,)
# 3        (rock,)
# 4         (pop,)
# 5        (punk,)
# ...          ...
# 1472     (rock,)
# 1473    (indie,)
# 1474     (folk,)
# 1475  (hip hop,)
# 1476    (indie,)
#
# [1031 rows x 6 columns]

# %%
grouped_one = one_genre.groupby('final_genre')['lyrics_eng'].sum().reset_index()
grouped_one.rename({'lyrics_eng': 'count'}, axis=1, inplace=True)
grouped_one['percentage'] = grouped_one['count'] / grouped_one['count'].sum() * 100
grouped_one.sort_values('percentage', ascending=False)
# Out:
#   final_genre  count  percentage
# 3    (indie,)   5198   18.923150
# 5      (pop,)   4735   17.237613
# 4    (metal,)   4567   16.626015
# 8     (rock,)   3387   12.330263
# 7      (rap,)   2914   10.608322
# 2  (hip hop,)   2694    9.807419
# 6     (punk,)   1757    6.396301
# 0  (country,)    762    2.774036
# 9     (soul,)    740    2.693946
# 1     (folk,)    715    2.602934

# %% [markdown]
# **Вопрос2** что делать с `mul_genre`

# %%
mul_genre = eng_genres_filtered[eng_genres_filtered['final_genre'].apply(lambda x: len(x) > 1)]

# %%
mul_genre['final_genre'] = mul_genre['final_genre'].apply(tuple)
grouped_mul = mul_genre.groupby('final_genre')['lyrics_eng'].sum().reset_index()
grouped_mul.rename({'lyrics_eng': 'count'}, axis=1, inplace=True)
grouped_mul['percentage'] = grouped_mul['count'] / grouped_mul['count'].sum() * 100
grouped_mul.sort_values('percentage', ascending=False)
# Out:
# <ipython-input-95-883ad6c4eb21>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mul_genre['final_genre'] = mul_genre['final_genre'].apply(tuple)
#            final_genre  count  percentage
# 7        (indie, rock)    444   16.075308
# 3         (indie, pop)    343   12.418537
# 15         (pop, punk)    308   11.151340
# 1        (indie, folk)    269    9.739319
# 12      (pop, country)    185    6.698045
# 24         (rock, pop)    121    4.380883
# 22        (rock, folk)    115    4.163650
# 11        (metal, rap)     92    3.330920
# 4    (indie, pop, rap)     73    2.643012
# 20         (rap, soul)     73    2.643012
# 17         (pop, soul)     69    2.498190
# 13         (pop, folk)     67    2.425778
# 2     (indie, hip hop)     66    2.389573
# 14          (pop, hip)     64    2.317161
# 19      (rap, country)     62    2.244750
# 18        (punk, folk)     60    2.172339
# 26         (rock, rap)     54    1.955105
# 21     (rock, country)     50    1.810282
# 9        (indie, soul)     49    1.774077
# 5        (indie, punk)     35    1.267198
# 16          (pop, rap)     34    1.230992
# 23     (rock, hip hop)     27    0.977552
# 8   (indie, rock, pop)     24    0.868936
# 10       (metal, folk)     23    0.832730
# 25        (rock, punk)     20    0.724113
# 6         (indie, rap)     18    0.651702
# 0      (folk, country)     17    0.615496

# %%
grouped_one = one_genre.groupby('final_genre')['lyrics_eng'].sum().reset_index()
grouped_one.rename({'lyrics_eng': 'count'}, axis=1, inplace=True)
grouped_one['percentage'] = grouped_one['count'] / grouped_one['count'].sum() * 100
grouped_one.sort_values('percentage', ascending=False)
# Out:
#   final_genre  count  percentage
# 5      (pop,)   4971   20.299739
# 4    (metal,)   3971   16.216106
# 8     (rock,)   3741   15.276870
# 7      (rap,)   3010   12.291735
# 3    (indie,)   2672   10.911467
# 2  (hip hop,)   2589   10.572525
# 6     (punk,)   1248    5.096374
# 0  (country,)    910    3.716106
# 9     (soul,)    787    3.213819
# 1     (folk,)    589    2.405260

# %%
mul_genre['final_genre'] = mul_genre['final_genre'].apply(tuple)
grouped_mul = mul_genre.groupby('final_genre')['lyrics_eng'].sum().reset_index()
grouped_mul.rename({'lyrics_eng': 'count'}, axis=1, inplace=True)
grouped_mul['percentage'] = grouped_mul['count'] / grouped_mul['count'].sum() * 100
grouped_mul.sort_values('percentage', ascending=False)
# Out:
# <ipython-input-162-883ad6c4eb21>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mul_genre['final_genre'] = mul_genre['final_genre'].apply(tuple)
#           final_genre  count  percentage
# 6       (indie, rock)    359   12.046980
# 13        (pop, punk)    335   11.241611
# 2        (indie, pop)    326   10.939597
# 0       (indie, folk)    257    8.624161
# 10     (pop, country)    199    6.677852
# 20       (rock, folk)    147    4.932886
# 22        (rock, pop)    146    4.899329
# 19    (rock, country)    143    4.798658
# 9        (metal, rap)    102    3.422819
# 14         (pop, rap)     98    3.288591
# 18        (rap, soul)     82    2.751678
# 1    (indie, hip hop)     80    2.684564
# 24        (rock, rap)     80    2.684564
# 4       (indie, punk)     78    2.617450
# 3   (indie, pop, rap)     76    2.550336
# 12         (pop, hip)     74    2.483221
# 15        (pop, soul)     72    2.416107
# 7       (indie, soul)     68    2.281879
# 16       (punk, folk)     67    2.248322
# 11        (pop, folk)     66    2.214765
# 17     (rap, country)     63    2.114094
# 8       (metal, folk)     55    1.845638
# 5        (indie, rap)      5    0.167785
# 21    (rock, hip hop)      1    0.033557
# 23       (rock, punk)      1    0.033557
